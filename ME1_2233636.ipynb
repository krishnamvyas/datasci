# %%
import pandas as pd
df=pd.read_csv('/content/Employee.csv')
df
# Out:
#       employee_id          name department  age    salary        city  gender  \
# 0           10001   Priya Verma      Sales   35  126156.0      Jaipur    Male
# 1           10002     Sai Patel  Marketing   46   38822.0   Bengaluru  Female
# 2           10003   Arjun Singh        R&D   56  110928.0   Hyderabad    Male
# 3           10004    Neha Verma    Finance   56   71586.0  Chandigarh    Male
# 4           10005   Priya Verma        R&D   52   47764.0       Delhi  Female
# ...           ...           ...        ...  ...       ...         ...     ...
# 3495        13496   Priya Verma         IT   24   31066.0  Chandigarh  Female
# 3496        13497     Sai Gupta    Support   21   48646.0      Mumbai    Male
# 3497        13498   Priya Mehta         HR   31  149886.0      Mumbai    Male
# 3498        13499  Vivaan Singh         HR   28   40735.0        Pune    Male
# 3499        13500   Kavya Mehta    Support   45  141726.0      Mumbai    Male
#
#             designation  experience_years
# 0        Data Scientist               5.0
# 1        Data Scientist               2.0
# 2        Data Scientist               5.0
# 3     Software Engineer               0.0
# 4               Analyst              17.0
# ...                 ...               ...
# 3495     Data Scientist               8.0
# 3496            Manager              18.0
# 3497            Manager              18.0
# 3498            Manager               1.0
# 3499                NaN              20.0
#
# [3500 rows x 9 columns]

# %%
df.to_excel('emp.xlsx', index=False)

# %%
df[df['age']> 40]
# Out:
#       employee_id           name department  age    salary        city  \
# 1           10002      Sai Patel  Marketing   46   38822.0   Bengaluru
# 2           10003    Arjun Singh        R&D   56  110928.0   Hyderabad
# 3           10004     Neha Verma    Finance   56   71586.0  Chandigarh
# 4           10005    Priya Verma        R&D   52   47764.0       Delhi
# 12          10013    Sneha Gupta      Sales   51   36823.0   Bengaluru
# ...           ...            ...        ...  ...       ...         ...
# 3490        13491      Ira Singh      Sales   47  103446.0   Bengaluru
# 3491        13492  Reyansh Patel    Finance   54   72292.0   Bengaluru
# 3492        13493   Ananya Mehta  Marketing   41  129406.0      Mumbai
# 3494        13495    Pooja Gupta    Support   42   36019.0     Kolkata
# 3499        13500    Kavya Mehta    Support   45  141726.0      Mumbai
#
#       gender        designation  experience_years
# 1     Female     Data Scientist               2.0
# 2       Male     Data Scientist               5.0
# 3       Male  Software Engineer               0.0
# 4     Female            Analyst              17.0
# 12    Female     Data Scientist              20.0
# ...      ...                ...               ...
# 3490  Female     Data Scientist              16.0
# 3491  Female       HR Executive               4.0
# 3492  Female     Data Scientist               0.0
# 3494  Female            Analyst               6.0
# 3499    Male                NaN              20.0
#
# [1770 rows x 9 columns]

# %%
df.sort_values(by='salary', ascending=False)
# Out:
#       employee_id           name  department  age    salary       city  \
# 1142        11143    Aanya Mehta          HR   60  149997.0    Chennai
# 2896        12897   Aditya Patel  Operations   50  149992.0    Chennai
# 3497        13498    Priya Mehta          HR   31  149886.0     Mumbai
# 914         10915   Ananya Singh       Sales   47  149796.0    Chennai
# 3292        13293   Ananya Singh     Finance   39  149736.0  Hyderabad
# ...           ...            ...         ...  ...       ...        ...
# 3372        13373   Sneha Sharma     Support   26       NaN    Chennai
# 3422        13423    Priya Patel     Support   30       NaN      Delhi
# 3423        13424     Diya Singh          IT   23       NaN      Delhi
# 3471        13472  Krishna Gupta   Marketing   52       NaN  Hyderabad
# 3484        13485    Sneha Patel     Finance   39       NaN      Delhi
#
#       gender        designation  experience_years
# 1142    Male     Data Scientist               6.0
# 2896  Female          Team Lead              19.0
# 3497    Male            Manager              18.0
# 914   Female  Software Engineer               3.0
# 3292  Female  Software Engineer               3.0
# ...      ...                ...               ...
# 3372  Female            Analyst               0.0
# 3422    Male  Software Engineer               1.0
# 3423  Female  Software Engineer               2.0
# 3471  Female  Software Engineer              17.0
# 3484    Male     Data Scientist               3.0
#
# [3500 rows x 9 columns]

# %%
df.sort_values(by=["salary", "name"], ascending=[False, True])
# Out:
#       employee_id          name  department  age    salary        city  \
# 1142        11143   Aanya Mehta          HR   60  149997.0     Chennai
# 2896        12897  Aditya Patel  Operations   50  149992.0     Chennai
# 3497        13498   Priya Mehta          HR   31  149886.0      Mumbai
# 914         10915  Ananya Singh       Sales   47  149796.0     Chennai
# 3292        13293  Ananya Singh     Finance   39  149736.0   Hyderabad
# ...           ...           ...         ...  ...       ...         ...
# 1536        11537  Vivaan Patel         R&D   48       NaN  Chandigarh
# 1521        11522  Vivaan Singh     Finance   53       NaN   Hyderabad
# 2797        12798  Vivaan Singh     Finance   44       NaN       Delhi
# 3079        13080  Vivaan Singh       Sales   49       NaN   Hyderabad
# 1080        11081  Vivaan Verma     Support   46       NaN   Hyderabad
#
#       gender        designation  experience_years
# 1142    Male     Data Scientist               6.0
# 2896  Female          Team Lead              19.0
# 3497    Male            Manager              18.0
# 914   Female  Software Engineer               3.0
# 3292  Female  Software Engineer               3.0
# ...      ...                ...               ...
# 1536  Female            Manager              16.0
# 1521    Male  Software Engineer               6.0
# 2797  Female       HR Executive              13.0
# 3079  Female       HR Executive               6.0
# 1080  Female          Team Lead              19.0
#
# [3500 rows x 9 columns]

# %%
df.groupby('department').count()
# Out:
#             employee_id  name  age  salary  city  gender  designation  \
# department
# Finance             435   435  435     415   410     435          416
# HR                  464   464  464     433   439     464          439
# IT                  412   412  412     389   385     412          392
# Marketing           445   445  445     424   429     445          425
# Operations          444   444  444     421   419     444          420
# R&D                 432   432  432     416   408     432          405
# Sales               443   443  443     423   424     443          423
# Support             425   425  425     404   411     425          405
#
#             experience_years
# department
# Finance                  407
# HR                       442
# IT                       386
# Marketing                420
# Operations               424
# R&D                      413
# Sales                    422
# Support                  411

# %%
df.head(50)
# Out:
#     employee_id            name  department  age    salary        city  \
# 0         10001     Priya Verma       Sales   35  126156.0      Jaipur
# 1         10002       Sai Patel   Marketing   46   38822.0   Bengaluru
# 2         10003     Arjun Singh         R&D   56  110928.0   Hyderabad
# 3         10004      Neha Verma     Finance   56   71586.0  Chandigarh
# 4         10005     Priya Verma         R&D   52   47764.0       Delhi
# 5         10006  Krishna Sharma          HR   34   31674.0        Pune
# 6         10007   Krishna Kumar     Finance   22  146708.0         NaN
# 7         10008      Diya Singh   Marketing   33   34683.0      Mumbai
# 8         10009    Vihaan Verma         R&D   38   89494.0   Ahmedabad
# 9         10010     Sneha Kumar       Sales   21   56660.0     Kolkata
# 10        10011    Ishaan Singh          IT   31   81591.0   Ahmedabad
# 11        10012  Muhammad Singh          IT   23   34290.0       Delhi
# 12        10013     Sneha Gupta       Sales   51   36823.0   Bengaluru
# 13        10014    Vihaan Singh   Marketing   49   48080.0     Chennai
# 14        10015     Kavya Patel         R&D   47  133622.0     Chennai
# 15        10016     Priya Singh          IT   47   49501.0  Chandigarh
# 16        10017     Kavya Verma     Finance   27   53071.0  Chandigarh
# 17        10018     Aarav Kumar          IT   25  101248.0      Mumbai
# 18        10019    Kavya Sharma   Marketing   35  105382.0        Pune
# 19        10020     Priya Singh     Support   43  122056.0   Hyderabad
# 20        10021     Pooja Verma         R&D   51  140148.0      Mumbai
# 21        10022     Aarav Kumar   Marketing   21   64334.0         NaN
# 22        10023  Muhammad Kumar  Operations   41   25813.0   Ahmedabad
# 23        10024   Krishna Singh          IT   49   52023.0        Pune
# 24        10025     Aanya Mehta          HR   25   30508.0   Hyderabad
# 25        10026    Kavya Sharma   Marketing   31  109337.0   Bengaluru
# 26        10027    Ishaan Verma         R&D   25   82449.0      Jaipur
# 27        10028   Vihaan Sharma   Marketing   51   88458.0       Delhi
# 28        10029     Priya Kumar     Support   22   52766.0   Bengaluru
# 29        10030    Ishaan Kumar     Finance   57   91465.0      Jaipur
# 30        10031   Reyansh Patel     Finance   43   36604.0   Ahmedabad
# 31        10032     Aarav Singh          HR   22   98145.0     Chennai
# 32        10033    Ishaan Verma  Operations   53   28178.0         NaN
# 33        10034      Diya Kumar          HR   36  104389.0   Hyderabad
# 34        10035    Ishaan Verma         R&D   26       NaN     Chennai
# 35        10036      Riya Patel         R&D   52   79792.0        Pune
# 36        10037    Aditya Kumar  Operations   53  137300.0     Kolkata
# 37        10038      Diya Singh          IT   25   51065.0      Mumbai
# 38        10039     Aarav Kumar          IT   27   90544.0   Ahmedabad
# 39        10040     Priya Singh   Marketing   39  117011.0   Ahmedabad
# 40        10041     Aanya Singh  Operations   34  111114.0     Chennai
# 41        10042       Ira Verma          IT   38  119920.0   Ahmedabad
# 42        10043    Priya Sharma       Sales   40  112129.0         NaN
# 43        10044     Sneha Singh     Support   37   35345.0       Delhi
# 44        10045     Neha Sharma          HR   24   56057.0      Jaipur
# 45        10046  Muhammad Patel     Finance   33   83751.0      Mumbai
# 46        10047       Ira Singh       Sales   25   54974.0        Pune
# 47        10048    Aditya Mehta       Sales   33  116755.0   Hyderabad
# 48        10049     Aarav Verma         R&D   45  129672.0     Kolkata
# 49        10050   Vivaan Sharma         R&D   31   85836.0      Mumbai
#
#     gender        designation  experience_years
# 0     Male     Data Scientist               5.0
# 1   Female     Data Scientist               2.0
# 2     Male     Data Scientist               5.0
# 3     Male  Software Engineer               0.0
# 4   Female            Analyst              17.0
# 5   Female     Data Scientist               1.0
# 6   Female            Analyst               5.0
# 7   Female  Software Engineer               2.0
# 8     Male     Data Scientist               3.0
# 9     Male          Team Lead               9.0
# 10  Female            Manager               1.0
# 11    Male            Analyst               2.0
# 12  Female     Data Scientist              20.0
# 13  Female            Analyst               NaN
# 14  Female                NaN               NaN
# 15  Female       HR Executive              13.0
# 16    Male       HR Executive              19.0
# 17  Female  Software Engineer              18.0
# 18  Female          Team Lead               8.0
# 19    Male          Team Lead              17.0
# 20    Male          Team Lead               3.0
# 21  Female       HR Executive               NaN
# 22  Female          Team Lead              16.0
# 23    Male       HR Executive               9.0
# 24  Female            Manager               0.0
# 25  Female            Analyst              14.0
# 26    Male            Manager               8.0
# 27  Female       HR Executive               7.0
# 28  Female          Team Lead              17.0
# 29  Female            Manager               9.0
# 30    Male            Analyst               7.0
# 31  Female            Manager               1.0
# 32  Female  Software Engineer               5.0
# 33    Male       HR Executive              12.0
# 34  Female  Software Engineer              12.0
# 35    Male       HR Executive               3.0
# 36    Male  Software Engineer              20.0
# 37  Female       HR Executive               4.0
# 38  Female     Data Scientist              17.0
# 39    Male     Data Scientist               NaN
# 40  Female          Team Lead               6.0
# 41  Female            Analyst               6.0
# 42    Male     Data Scientist               3.0
# 43    Male            Manager               8.0
# 44    Male            Manager              18.0
# 45  Female            Analyst               NaN
# 46    Male            Analyst              16.0
# 47  Female  Software Engineer               NaN
# 48  Female       HR Executive              14.0
# 49  Female  Software Engineer               2.0

# %%
df.shape
# Out:
# (3500, 9)

# %%
df.isnull()
df.isnull().sum()
# Out:
# employee_id           0
# name                  0
# department            0
# age                   0
# salary              175
# city                175
# gender                0
# designation         175
# experience_years    175
# dtype: int64

# %%
df.dropna()
# Out:
#       employee_id          name department  age    salary        city  gender  \
# 0           10001   Priya Verma      Sales   35  126156.0      Jaipur    Male
# 1           10002     Sai Patel  Marketing   46   38822.0   Bengaluru  Female
# 2           10003   Arjun Singh        R&D   56  110928.0   Hyderabad    Male
# 3           10004    Neha Verma    Finance   56   71586.0  Chandigarh    Male
# 4           10005   Priya Verma        R&D   52   47764.0       Delhi  Female
# ...           ...           ...        ...  ...       ...         ...     ...
# 3494        13495   Pooja Gupta    Support   42   36019.0     Kolkata  Female
# 3495        13496   Priya Verma         IT   24   31066.0  Chandigarh  Female
# 3496        13497     Sai Gupta    Support   21   48646.0      Mumbai    Male
# 3497        13498   Priya Mehta         HR   31  149886.0      Mumbai    Male
# 3498        13499  Vivaan Singh         HR   28   40735.0        Pune    Male
#
#             designation  experience_years
# 0        Data Scientist               5.0
# 1        Data Scientist               2.0
# 2        Data Scientist               5.0
# 3     Software Engineer               0.0
# 4               Analyst              17.0
# ...                 ...               ...
# 3494            Analyst               6.0
# 3495     Data Scientist               8.0
# 3496            Manager              18.0
# 3497            Manager              18.0
# 3498            Manager               1.0
#
# [2842 rows x 9 columns]

# %%
df.fillna({"salary": 1000000}, inplace=False)
# Out:
#       employee_id          name department  age    salary        city  gender  \
# 0           10001   Priya Verma      Sales   35  126156.0      Jaipur    Male
# 1           10002     Sai Patel  Marketing   46   38822.0   Bengaluru  Female
# 2           10003   Arjun Singh        R&D   56  110928.0   Hyderabad    Male
# 3           10004    Neha Verma    Finance   56   71586.0  Chandigarh    Male
# 4           10005   Priya Verma        R&D   52   47764.0       Delhi  Female
# ...           ...           ...        ...  ...       ...         ...     ...
# 3495        13496   Priya Verma         IT   24   31066.0  Chandigarh  Female
# 3496        13497     Sai Gupta    Support   21   48646.0      Mumbai    Male
# 3497        13498   Priya Mehta         HR   31  149886.0      Mumbai    Male
# 3498        13499  Vivaan Singh         HR   28   40735.0        Pune    Male
# 3499        13500   Kavya Mehta    Support   45  141726.0      Mumbai    Male
#
#             designation  experience_years
# 0        Data Scientist               5.0
# 1        Data Scientist               2.0
# 2        Data Scientist               5.0
# 3     Software Engineer               0.0
# 4               Analyst              17.0
# ...                 ...               ...
# 3495     Data Scientist               8.0
# 3496            Manager              18.0
# 3497            Manager              18.0
# 3498            Manager               1.0
# 3499                NaN              20.0
#
# [3500 rows x 9 columns]

# %%
df["name"]
# Out:
# 0        Priya Verma
# 1          Sai Patel
# 2        Arjun Singh
# 3         Neha Verma
# 4        Priya Verma
#             ...
# 3495     Priya Verma
# 3496       Sai Gupta
# 3497     Priya Mehta
# 3498    Vivaan Singh
# 3499     Kavya Mehta
# Name: name, Length: 3500, dtype: object

# %%
data = {
    "EmployeeID": [101, 102, 103, 104, 105],
    "Name": ["Amit", "Neha", "Rahul", "Priya", "Karan"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Age": [25, 30, 35, 28, 40],
    "Salary": [45000, 55000, 60000, 52000, None]
}

df1 = pd.DataFrame(data)

# %%
df1.head(3)
# Out:
#    EmployeeID   Name Department  Age   Salary
# 0         101   Amit         IT   25  45000.0
# 1         102   Neha         HR   30  55000.0
# 2         103  Rahul         IT   35  60000.0

# %%
df1["Salary"].mean()
# Out:
# np.float64(53000.0)

# %%
df1[df1["Salary"] > 50000]
# Out:
#    EmployeeID   Name Department  Age   Salary
# 1         102   Neha         HR   30  55000.0
# 2         103  Rahul         IT   35  60000.0
# 3         104  Priya    Finance   28  52000.0

# %%
df1.sort_values(by="Age")
# Out:
#    EmployeeID   Name Department  Age   Salary
# 0         101   Amit         IT   25  45000.0
# 3         104  Priya    Finance   28  52000.0
# 1         102   Neha         HR   30  55000.0
# 2         103  Rahul         IT   35  60000.0
# 4         105  Karan         HR   40      NaN

# %%
df1.groupby("Department")["Salary"].sum()
# Out:
# Department
# Finance     52000.0
# HR          55000.0
# IT         105000.0
# Name: Salary, dtype: float64

# %%
df1["Bonus"] = df1["Salary"] * 0.10
df1
# Out:
#    EmployeeID   Name Department  Age   Salary   Bonus
# 0         101   Amit         IT   25  45000.0  4500.0
# 1         102   Neha         HR   30  55000.0  5500.0
# 2         103  Rahul         IT   35  60000.0  6000.0
# 3         104  Priya    Finance   28  52000.0  5200.0
# 4         105  Karan         HR   40      NaN     NaN

# %%
df1["Salary"] = df1["Salary"].fillna(df1["Salary"].mean())
df1
# Out:
#    EmployeeID   Name Department  Age   Salary   Bonus
# 0         101   Amit         IT   25  45000.0  4500.0
# 1         102   Neha         HR   30  55000.0  5500.0
# 2         103  Rahul         IT   35  60000.0  6000.0
# 3         104  Priya    Finance   28  52000.0  5200.0
# 4         105  Karan         HR   40  53000.0     NaN

# %%
df1.rename(columns={"EmployeeID": "ID"}, inplace=True)
df1
# Out:
#     ID   Name Department  Age   Salary   Bonus
# 0  101   Amit         IT   25  45000.0  4500.0
# 1  102   Neha         HR   30  55000.0  5500.0
# 2  103  Rahul         IT   35  60000.0  6000.0
# 3  104  Priya    Finance   28  52000.0  5200.0
# 4  105  Karan         HR   40  53000.0     NaN
